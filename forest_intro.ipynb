# %%
import sys
sys.path.append("./src")
from evogp.tree import Tree, Forest

# random generate a Forest with 10 trees
generate_configs = {
    "const_prob": 0.5,
    "out_prob": 0.5,
    "func_prob": {"+": 0.25, "-": 0.25, "*": 0.25, "/": 0.25},
    "layer_leaf_prob": 0.2,
    "const_range": (-1, 1),
    "sample_cnt": 8,
}

forest = Forest.random_generate(
    pop_size=10,
    gp_len=128,
    input_len=3,
    output_len=1,
    max_layer_cnt=5,
    **generate_configs,
)

# %%
# the forest can be print or transform to a str
print(forest)
string_forest = str(forest)
print(string_forest)
# Out:
# Forest(pop size: 10)
# [
#   + - - - x[0] * x[1] x[2] / 0.19 0.19 * + * 0.00 x[0] * x[1] 0.19 * * x[2] x[1] + 0.43 x[2] * / - - x[2] x[0] x[1] / * x[2] x[2] * -0.28 x[0] + / + 0.19 x[0] / x[1] 0.00 * + -0.75 0.08 + 0.48 x[1] ,
#   / - x[1] * x[0] - x[1] + x[0] 0.19 / / * -0.82 + -0.82 x[1] 0.43 x[1] ,
#   + + + -0.75 -0.28 - x[1] * * 0.48 x[0] + x[2] 0.00 + - + / 0.00 0.08 / -0.75 -0.82 * / x[2] -0.82 + x[2] -0.75 * * * 0.43 -0.28 0.00 * / x[0] -0.28 - 0.43 x[2] ,
#   x[2] ,
#   * - / - / x[0] x[2] / 0.19 0.19 * x[0] + -0.82 x[0] * / -0.75 * -0.82 -0.82 / - 0.08 x[1] x[1] 0.19 ,
#   / - + / / -0.28 x[0] / x[2] x[1] * x[0] + x[0] x[2] / x[2] / x[0] / -0.28 x[2] + * / x[1] 0.48 / * x[0] x[0] / 0.19 x[0] x[2] ,
#   * 0.19 x[2] ,
#   - / / * - 0.19 0.48 x[1] - * x[0] x[1] - x[2] x[1] * + - 0.00 x[2] * 0.19 0.19 - 0.43 x[2] + -0.82 x[0] ,
#   / x[0] - * * * x[2] 0.00 + x[0] x[0] - * -0.82 x[1] -0.28 x[1] ,
#   x[1] ,
# ]
# Forest(pop size: 10)
# [
#   + - - - x[0] * x[1] x[2] / 0.19 0.19 * + * 0.00 x[0] * x[1] 0.19 * * x[2] x[1] + 0.43 x[2] * / - - x[2] x[0] x[1] / * x[2] x[2] * -0.28 x[0] + / + 0.19 x[0] / x[1] 0.00 * + -0.75 0.08 + 0.48 x[1] ,
#   / - x[1] * x[0] - x[1] + x[0] 0.19 / / * -0.82 + -0.82 x[1] 0.43 x[1] ,
#   + + + -0.75 -0.28 - x[1] * * 0.48 x[0] + x[2] 0.00 + - + / 0.00 0.08 / -0.75 -0.82 * / x[2] -0.82 + x[2] -0.75 * * * 0.43 -0.28 0.00 * / x[0] -0.28 - 0.43 x[2] ,
#   x[2] ,
#   * - / - / x[0] x[2] / 0.19 0.19 * x[0] + -0.82 x[0] * / -0.75 * -0.82 -0.82 / - 0.08 x[1] x[1] 0.19 ,
#   / - + / / -0.28 x[0] / x[2] x[1] * x[0] + x[0] x[2] / x[2] / x[0] / -0.28 x[2] + * / x[1] 0.48 / * x[0] x[0] / 0.19 x[0] x[2] ,
#   * 0.19 x[2] ,
#   - / / * - 0.19 0.48 x[1] - * x[0] x[1] - x[2] x[1] * + - 0.00 x[2] * 0.19 0.19 - 0.43 x[2] + -0.82 x[0] ,
#   / x[0] - * * * x[2] 0.00 + x[0] x[0] - * -0.82 x[1] -0.28 x[1] ,
#   x[1] ,
# ]

# %%
# the forest support __getitem__ method

# get one item from the forest, will obtain a tree
tree = forest[0]
print(tree)
# Out:
# + - - - x[0] * x[1] x[2] / 0.19 0.19 * + * 0.00 x[0] * x[1] 0.19 * * x[2] x[1] + 0.43 x[2] * / - - x[2] x[0] x[1] / * x[2] x[2] * -0.28 x[0] + / + 0.19 x[0] / x[1] 0.00 * + -0.75 0.08 + 0.48 x[1]

# %%
# get multiple items from forest, will obtain another forest

sub_forest = forest[:3]
print(sub_forest)
# Out:
# Forest(pop size: 3)
# [
#   + - - - x[0] * x[1] x[2] / 0.19 0.19 * + * 0.00 x[0] * x[1] 0.19 * * x[2] x[1] + 0.43 x[2] * / - - x[2] x[0] x[1] / * x[2] x[2] * -0.28 x[0] + / + 0.19 x[0] / x[1] 0.00 * + -0.75 0.08 + 0.48 x[1] ,
#   / - x[1] * x[0] - x[1] + x[0] 0.19 / / * -0.82 + -0.82 x[1] 0.43 x[1] ,
#   + + + -0.75 -0.28 - x[1] * * 0.48 x[0] + x[2] 0.00 + - + / 0.00 0.08 / -0.75 -0.82 * / x[2] -0.82 + x[2] -0.75 * * * 0.43 -0.28 0.00 * / x[0] -0.28 - 0.43 x[2] ,
# ]

# %%
# the forest support __setitem__ method

# set a Tree in the forest
forest[-1] = tree
print(forest)
# Out:
# Forest(pop size: 10)
# [
#   + - - - x[0] * x[1] x[2] / 0.19 0.19 * + * 0.00 x[0] * x[1] 0.19 * * x[2] x[1] + 0.43 x[2] * / - - x[2] x[0] x[1] / * x[2] x[2] * -0.28 x[0] + / + 0.19 x[0] / x[1] 0.00 * + -0.75 0.08 + 0.48 x[1] ,
#   / - x[1] * x[0] - x[1] + x[0] 0.19 / / * -0.82 + -0.82 x[1] 0.43 x[1] ,
#   + + + -0.75 -0.28 - x[1] * * 0.48 x[0] + x[2] 0.00 + - + / 0.00 0.08 / -0.75 -0.82 * / x[2] -0.82 + x[2] -0.75 * * * 0.43 -0.28 0.00 * / x[0] -0.28 - 0.43 x[2] ,
#   x[2] ,
#   * - / - / x[0] x[2] / 0.19 0.19 * x[0] + -0.82 x[0] * / -0.75 * -0.82 -0.82 / - 0.08 x[1] x[1] 0.19 ,
#   / - + / / -0.28 x[0] / x[2] x[1] * x[0] + x[0] x[2] / x[2] / x[0] / -0.28 x[2] + * / x[1] 0.48 / * x[0] x[0] / 0.19 x[0] x[2] ,
#   * 0.19 x[2] ,
#   - / / * - 0.19 0.48 x[1] - * x[0] x[1] - x[2] x[1] * + - 0.00 x[2] * 0.19 0.19 - 0.43 x[2] + -0.82 x[0] ,
#   / x[0] - * * * x[2] 0.00 + x[0] x[0] - * -0.82 x[1] -0.28 x[1] ,
#   + - - - x[0] * x[1] x[2] / 0.19 0.19 * + * 0.00 x[0] * x[1] 0.19 * * x[2] x[1] + 0.43 x[2] * / - - x[2] x[0] x[1] / * x[2] x[2] * -0.28 x[0] + / + 0.19 x[0] / x[1] 0.00 * + -0.75 0.08 + 0.48 x[1] ,
# ]

# %%
# set a forest in the forest
forest[-3:] = sub_forest
forest
# Out:
# Forest(pop size: 10)
# [
#   + - - - x[0] * x[1] x[2] / 0.19 0.19 * + * 0.00 x[0] * x[1] 0.19 * * x[2] x[1] + 0.43 x[2] * / - - x[2] x[0] x[1] / * x[2] x[2] * -0.28 x[0] + / + 0.19 x[0] / x[1] 0.00 * + -0.75 0.08 + 0.48 x[1] ,
#   / - x[1] * x[0] - x[1] + x[0] 0.19 / / * -0.82 + -0.82 x[1] 0.43 x[1] ,
#   + + + -0.75 -0.28 - x[1] * * 0.48 x[0] + x[2] 0.00 + - + / 0.00 0.08 / -0.75 -0.82 * / x[2] -0.82 + x[2] -0.75 * * * 0.43 -0.28 0.00 * / x[0] -0.28 - 0.43 x[2] ,
#   x[2] ,
#   * - / - / x[0] x[2] / 0.19 0.19 * x[0] + -0.82 x[0] * / -0.75 * -0.82 -0.82 / - 0.08 x[1] x[1] 0.19 ,
#   / - + / / -0.28 x[0] / x[2] x[1] * x[0] + x[0] x[2] / x[2] / x[0] / -0.28 x[2] + * / x[1] 0.48 / * x[0] x[0] / 0.19 x[0] x[2] ,
#   * 0.19 x[2] ,
#   + - - - x[0] * x[1] x[2] / 0.19 0.19 * + * 0.00 x[0] * x[1] 0.19 * * x[2] x[1] + 0.43 x[2] * / - - x[2] x[0] x[1] / * x[2] x[2] * -0.28 x[0] + / + 0.19 x[0] / x[1] 0.00 * + -0.75 0.08 + 0.48 x[1] ,
#   / - x[1] * x[0] - x[1] + x[0] 0.19 / / * -0.82 + -0.82 x[1] 0.43 x[1] ,
#   + + + -0.75 -0.28 - x[1] * * 0.48 x[0] + x[2] 0.00 + - + / 0.00 0.08 / -0.75 -0.82 * / x[2] -0.82 + x[2] -0.75 * * * 0.43 -0.28 0.00 * / x[0] -0.28 - 0.43 x[2] ,
# ]

# %%
# forest support __add__ operation
forest = forest + tree
forest = forest + sub_forest
forest
# Out:
# Forest(pop size: 14)
# [
#   + - - - x[0] * x[1] x[2] / 0.19 0.19 * + * 0.00 x[0] * x[1] 0.19 * * x[2] x[1] + 0.43 x[2] * / - - x[2] x[0] x[1] / * x[2] x[2] * -0.28 x[0] + / + 0.19 x[0] / x[1] 0.00 * + -0.75 0.08 + 0.48 x[1] ,
#   / - x[1] * x[0] - x[1] + x[0] 0.19 / / * -0.82 + -0.82 x[1] 0.43 x[1] ,
#   + + + -0.75 -0.28 - x[1] * * 0.48 x[0] + x[2] 0.00 + - + / 0.00 0.08 / -0.75 -0.82 * / x[2] -0.82 + x[2] -0.75 * * * 0.43 -0.28 0.00 * / x[0] -0.28 - 0.43 x[2] ,
#   x[2] ,
#   * - / - / x[0] x[2] / 0.19 0.19 * x[0] + -0.82 x[0] * / -0.75 * -0.82 -0.82 / - 0.08 x[1] x[1] 0.19 ,
#   / - + / / -0.28 x[0] / x[2] x[1] * x[0] + x[0] x[2] / x[2] / x[0] / -0.28 x[2] + * / x[1] 0.48 / * x[0] x[0] / 0.19 x[0] x[2] ,
#   * 0.19 x[2] ,
#   + - - - x[0] * x[1] x[2] / 0.19 0.19 * + * 0.00 x[0] * x[1] 0.19 * * x[2] x[1] + 0.43 x[2] * / - - x[2] x[0] x[1] / * x[2] x[2] * -0.28 x[0] + / + 0.19 x[0] / x[1] 0.00 * + -0.75 0.08 + 0.48 x[1] ,
#   / - x[1] * x[0] - x[1] + x[0] 0.19 / / * -0.82 + -0.82 x[1] 0.43 x[1] ,
#   + + + -0.75 -0.28 - x[1] * * 0.48 x[0] + x[2] 0.00 + - + / 0.00 0.08 / -0.75 -0.82 * / x[2] -0.82 + x[2] -0.75 * * * 0.43 -0.28 0.00 * / x[0] -0.28 - 0.43 x[2] ,
#   + - - - x[0] * x[1] x[2] / 0.19 0.19 * + * 0.00 x[0] * x[1] 0.19 * * x[2] x[1] + 0.43 x[2] * / - - x[2] x[0] x[1] / * x[2] x[2] * -0.28 x[0] + / + 0.19 x[0] / x[1] 0.00 * + -0.75 0.08 + 0.48 x[1] ,
#   + - - - x[0] * x[1] x[2] / 0.19 0.19 * + * 0.00 x[0] * x[1] 0.19 * * x[2] x[1] + 0.43 x[2] * / - - x[2] x[0] x[1] / * x[2] x[2] * -0.28 x[0] + / + 0.19 x[0] / x[1] 0.00 * + -0.75 0.08 + 0.48 x[1] ,
#   / - x[1] * x[0] - x[1] + x[0] 0.19 / / * -0.82 + -0.82 x[1] 0.43 x[1] ,
#   + + + -0.75 -0.28 - x[1] * * 0.48 x[0] + x[2] 0.00 + - + / 0.00 0.08 / -0.75 -0.82 * / x[2] -0.82 + x[2] -0.75 * * * 0.43 -0.28 0.00 * / x[0] -0.28 - 0.43 x[2] ,
# ]
